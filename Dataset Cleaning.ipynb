# %% [markdown]
# /Resources/spotify-2023.csv

# %%
# import polars as pl
import pandas as pd
import numpy as np
import os 
# import requests

# %%
# Provide the path to your CSV file
csv1_path = 'universal_top_spotify_songs.csv'
csv2_path = 'million_spotify_data.csv'

# Read the CSV file into a Polars DataFrame
# pldf = pl.read_csv(csv_path)
df1 = pd.read_csv(csv1_path)
df2 = pd.read_csv(csv2_path)
# Display the DataFrame
# print(df)
df2.head()
# Out:
#    Unnamed: 0    artist_name        track_name                track_id  \
# 0           0     Jason Mraz   I Won't Give Up  53QF56cjZA9RTuuMZDrSA6
# 1           1     Jason Mraz  93 Million Miles  1s8tP3jP4GZcyHDsjvw218
# 2           2  Joshua Hyslop  Do Not Let Me Go  7BRCa8MPiyuvr2VU3O9W0F
# 3           3   Boyce Avenue          Fast Car  63wsZUhUZLlh1OsyrZq7sz
# 4           4   Andrew Belle  Sky's Still Blue  6nXIYClvJAfi6ujLiKqEq8
#
#    popularity  year     genre  danceability  energy  key  loudness  mode  \
# 0          68  2012  acoustic         0.483   0.303    4   -10.058     1
# 1          50  2012  acoustic         0.572   0.454    3   -10.286     1
# 2          57  2012  acoustic         0.409   0.234    3   -13.711     1
# 3          58  2012  acoustic         0.392   0.251   10    -9.845     1
# 4          54  2012  acoustic         0.430   0.791    6    -5.419     0
#
#    speechiness  acousticness  instrumentalness  liveness  valence    tempo  \
# ...

# %%
df1.columns
# Out:
# Index(['spotify_id', 'name', 'artists', 'daily_rank', 'daily_movement',
#        'weekly_movement', 'country', 'snapshot_date', 'popularity',
#        'is_explicit', 'duration_ms', 'album_name', 'album_release_date',
#        'danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness',
#        'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo',
#        'time_signature'],
#       dtype='object')

# %%
df1
# Out:
#                     spotify_id                               name  \
# 0       0bYg9bo50gSsH3LtXe2SQn    All I Want for Christmas Is You
# 1       06qMRF18gwbOYYbnP2du6i    Last Christmas - Single Version
# 2       2EjXfH91m7f8HiJN1yQg97  Rockin' Around The Christmas Tree
# 3       7vQbuQcyTflfCIOu3Uzzya                   Jingle Bell Rock
# 4       0lizgQ7Qw35od7CYaoMBZb                      Santa Tell Me
# ...                        ...                                ...
# 229478  0AYt6NMyyLd0rLuvr0UkMH          Slime You Out (feat. SZA)
# 229479  2Gk6fi0dqt91NKvlzGsmm7  SAY MY GRACE (feat. Travis Scott)
# 229480  26b3oVLrRUaaybJulow9kz                             People
# 229481  5ydjxBSUIDn26MFzU3asP4                         Rainy Days
# 229482  59NraMJsLaMCVtwXTSia8i                              Prada
#
#                             artists  daily_rank  daily_movement  \
# 0                      Mariah Carey           1               0
# ...

# %%
df1.dropna(inplace=True)
df1
# Out:
#                     spotify_id  \
# 50      6Kijtp0DB6VwcoJIw7PJ9W
# 51      0UBK6HcgmmWUQzFQTncmDz
# 52      5yyYL1FpimADTIftYQU0cg
# 53      4tsVMjM60RNTe9EV5oQ4sQ
# 54      7JbLSEDlRdoJaXk5ddZae2
# ...                        ...
# 229478  0AYt6NMyyLd0rLuvr0UkMH
# 229479  2Gk6fi0dqt91NKvlzGsmm7
# 229480  26b3oVLrRUaaybJulow9kz
# 229481  5ydjxBSUIDn26MFzU3asP4
# 229482  59NraMJsLaMCVtwXTSia8i
#
#                                                      name  \
# 50      Imithandazo (feat. Young Stunna, DJ Maphorisa,...
# 51                            Keneilwe (feat. Dalom Kids)
# 52                                                  iPlan
# 53                                            Masithokoze
# 54                                                  Paris
# ...                                                   ...
# 229478                          Slime You Out (feat. SZA)
# 229479                  SAY MY GRACE (feat. Travis Scott)
# ...

# %%
df1['country'].unique()
# Out:
# array(['ZA', 'VN', 'VE', 'UY', 'US', 'UA', 'TW', 'TR', 'TH', 'SV', 'SK',
#        'SG', 'SE', 'SA', 'RO', 'PY', 'PT', 'PL', 'PK', 'PH', 'PE', 'PA',
#        'NZ', 'NO', 'NL', 'NI', 'NG', 'MY', 'MX', 'MA', 'LV', 'LU', 'LT',
#        'KZ', 'KR', 'JP', 'IT', 'IS', 'IN', 'IL', 'IE', 'ID', 'HU', 'HN',
#        'HK', 'GT', 'GR', 'GB', 'FR', 'FI', 'ES', 'EG', 'EE', 'EC', 'DO',
#        'DK', 'DE', 'CZ', 'CR', 'CO', 'CL', 'CH', 'CA', 'BY', 'BR', 'BO',
#        'BG', 'BE', 'AU', 'AT', 'AR', 'AE'], dtype=object)

# %%
df1.shape
# Out:
# (226285, 25)

# %%
df2['genre'].unique()
# Out:
# array(['acoustic', 'afrobeat', 'alt-rock', 'ambient', 'black-metal',
#        'blues', 'breakbeat', 'cantopop', 'chicago-house', 'chill',
#        'classical', 'club', 'comedy', 'country', 'dance', 'dancehall',
#        'death-metal', 'deep-house', 'detroit-techno', 'disco',
#        'drum-and-bass', 'dub', 'dubstep', 'edm', 'electro', 'electronic',
#        'emo', 'folk', 'forro', 'french', 'funk', 'garage', 'german',
#        'gospel', 'goth', 'grindcore', 'groove', 'guitar', 'hard-rock',
#        'hardcore', 'hardstyle', 'heavy-metal', 'hip-hop', 'house',
#        'indian', 'indie-pop', 'industrial', 'jazz', 'k-pop', 'metal',
#        'metalcore', 'minimal-techno', 'new-age', 'opera', 'party',
#        'piano', 'pop', 'pop-film', 'power-pop', 'progressive-house',
#        'psych-rock', 'punk', 'punk-rock', 'rock', 'rock-n-roll',
#        'romance', 'sad', 'salsa', 'samba', 'sertanejo', 'show-tunes',
#        'singer-songwriter', 'ska', 'sleep', 'songwriter', 'soul',
# ...

# %%
df2.rename(columns={'track_id': 'spotify_id'}, inplace=True)
df2
# Out:
#          Unnamed: 0      artist_name                         track_name  \
# 0                 0       Jason Mraz                    I Won't Give Up
# 1                 1       Jason Mraz                   93 Million Miles
# 2                 2    Joshua Hyslop                   Do Not Let Me Go
# 3                 3     Boyce Avenue                           Fast Car
# 4                 4     Andrew Belle                   Sky's Still Blue
# ...             ...              ...                                ...
# 1159759     1473391     Nicola Conte                      Black Spirits
# 1159760     1473392     Nicola Conte                         Quiet Dawn
# 1159761     1473393       Amon Tobin                  Morning Ms Candis
# 1159762     1473394  Peace Orchestra      Happy Christmas (War Is Over)
# 1159763     1473395     Mo' Horizons  Hit the Road Jack (Pé Na Éstrada)
#
#                      spotify_id  popularity  year     genre  danceability  \
# ...

# %%
df2.dropna(inplace=True)
df2
# Out:
#          Unnamed: 0      artist_name                         track_name  \
# 0                 0       Jason Mraz                    I Won't Give Up
# 1                 1       Jason Mraz                   93 Million Miles
# 2                 2    Joshua Hyslop                   Do Not Let Me Go
# 3                 3     Boyce Avenue                           Fast Car
# 4                 4     Andrew Belle                   Sky's Still Blue
# ...             ...              ...                                ...
# 1159759     1473391     Nicola Conte                      Black Spirits
# 1159760     1473392     Nicola Conte                         Quiet Dawn
# 1159761     1473393       Amon Tobin                  Morning Ms Candis
# 1159762     1473394  Peace Orchestra      Happy Christmas (War Is Over)
# 1159763     1473395     Mo' Horizons  Hit the Road Jack (Pé Na Éstrada)
#
#                      spotify_id  popularity  year     genre  danceability  \
# ...

# %%
merged_df = pd.merge(df1, df2[['spotify_id', 'genre']], how='left', on='spotify_id')
merged_df.head()
# Out:
#                spotify_id                                               name  \
# 0  6Kijtp0DB6VwcoJIw7PJ9W  Imithandazo (feat. Young Stunna, DJ Maphorisa,...
# 1  0UBK6HcgmmWUQzFQTncmDz                        Keneilwe (feat. Dalom Kids)
# 2  5yyYL1FpimADTIftYQU0cg                                              iPlan
# 3  4tsVMjM60RNTe9EV5oQ4sQ                                        Masithokoze
# 4  7JbLSEDlRdoJaXk5ddZae2                                              Paris
#
#                                              artists  daily_rank  \
# 0  Kabza De Small, Mthunzi, DJ Maphorisa, Young S...           1
# 1  Wanitwa Mos, Nkosazana Daughter, Master KG, Da...           2
# 2                         Dlala Thukzin, Zaba, Sykes           3
# 3                                   DJ Stokie, Eemoh           4
# 4                       Mthandeni SK, Lwah Ndlunkulu           5
#
#    daily_movement  weekly_movement country snapshot_date  popularity  \
# ...

# %%
merged_df.shape
# Out:
# (226285, 26)

# %%
merged_df.dropna(inplace=True)

# %%
merged_df.shape
# Out:
# (24314, 26)

# %%
merged_df['country'].unique()
# No nan values observed
# Out:
# array(['ZA', 'VN', 'VE', 'US', 'UA', 'TW', 'TR', 'TH', 'SV', 'SK', 'SG',
#        'SE', 'SA', 'RO', 'PY', 'PT', 'PL', 'PK', 'PH', 'PE', 'PA', 'NZ',
#        'NO', 'NL', 'NI', 'MY', 'MX', 'MA', 'LV', 'LU', 'LT', 'KZ', 'KR',
#        'JP', 'IT', 'IS', 'IN', 'IL', 'IE', 'ID', 'HU', 'HN', 'HK', 'GT',
#        'GB', 'FR', 'FI', 'EE', 'EC', 'DO', 'DK', 'DE', 'CZ', 'CR', 'CO',
#        'CH', 'CA', 'BY', 'BR', 'BO', 'BG', 'BE', 'AU', 'AT', 'AE', 'EG',
#        'CL', 'AR', 'ES'], dtype=object)

# %%
merged_df['genre'].unique()
# No nan values observed
# Out:
# array(['soul', 'pop', 'indie-pop', 'dance', 'jazz', 'hip-hop', 'country',
#        'punk', 'garage', 'k-pop', 'singer-songwriter', 'alt-rock',
#        'german', 'folk', 'emo', 'swedish', 'electro', 'pop-film',
#        'indian', 'rock', 'sad', 'french', 'cantopop', 'acoustic',
#        'sertanejo', 'piano', 'deep-house', 'forro', 'funk', 'punk-rock',
#        'chill', 'power-pop'], dtype=object)

# %%
# merged_df.reset_index().head(20)

# %%
# Create a folder
if not os.path.exists("Resources"):
    os.makedirs("Resources")

# %%
# Store the merged_df into a csv file
csv_file_path = 'Resources/spotify_condensed_data.csv'
merged_df.to_csv(csv_file_path)
